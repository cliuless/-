# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import numpy as np
import os
import wget

# %%
df = pd.read_pickle('chuansong_url.p')

# %%
>>> import wget
>>> url = 'http://www.futurecrew.com/skaven/song_files/mp3/razorback.mp3'
>>> filename = wget.download(url)
100% [................................................] 3841532 / 3841532>
>> filename
'razorback.mp3'

# %%
url = 'http://chuansong.me/n/2223940043013'

# %%
from urllib.request import Request, urlopen

req = Request(url, 
              headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# %%
webpage
# Out:
# b'<!DOCTYPE html>\n<html lang="zh-CN">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta name="sogou_site_verification" content="hhvxQaTyZg"/>\n<meta name="baidu-site-verification" content="zFBlTrLmns" />\n<link href="/static/css/inspector.css" rel="stylesheet" type="text/css">\n<link href="/static/css/main.css" rel="stylesheet" type="text/css">\n<link href="/static/css/base.css" rel="stylesheet" type="text/css">\n<!--[if IE]>\n<link href="/static/css/ie.css" rel="stylesheet" type="text/css">\n<![endif]-->\n<!-- Le fav and touch icons -->\n<link rel="apple-touch-icon-precomposed" sizes="144x144" href="/static/img/ico/apple-touch-icon-ipad3.png">\n<link rel="apple-touch-icon-precomposed" sizes="114x114" href="/static/img/ico/apple-touch-icon-iphone4.png">\n<link rel="apple-touch-icon-precomposed" sizes="72x72" href="/static/img/ico/apple-touch-icon-ipad.png">\n<link rel="apple-touch-icon-precomposed" href="/static/img/ico/apple-touch-icon-iphone.png">
# ...

# %%
article_title = []
article_date = []
article_url = []


# mv chrome driver from Downloads to Applications 
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver


driver = webdriver.Chrome(chromedriver)
driver.get("http://chuansong.me/account/genderinchina")
# driver.get("https://mail.google.com")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-228-c36efe30f5c6> in <module>()
#      16
#      17 driver = webdriver.Chrome(chromedriver)
# ---> 18 driver.get("http://chuansong.me/account/genderinchina")
#      19 # driver.get("https://mail.google.com")
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     322         Loads a web page in the current browser session.
#     323         """
# --> 324         self.execute(Command.GET, {'url': url})
#     325
#     326     @property
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
# ...

# %%
for i in range(1,88):
    links = driver.find_elements_by_class_name("question_link")
    dates = driver.find_elements_by_class_name("timestamp")
    article_date.extend([i.text for i in dates])
    article_url.extend([i.get_attribute('href') for i in links])
    article_title.extend([i.text for i in links])
    next_page = driver.find_element_by_xpath('//div/a[contains(text(),"下一页")]')
    next_page.click()

# %%
hi = driver.find_elements_by_class_name("question_link")

# %%
hi[0].source
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-227-6422e5c8a191> in <module>()
# ----> 1 hi[0].source
#
# AttributeError: 'WebElement' object has no attribute 'source'

# %%
import pandas as pd

# %%
df = list(zip(article_date, article_url, article_title))
df = pd.DataFrame(df,columns = ['Date', 'URL', 'Title'])
df.to_pickle('chuansong_url.p')

# %%
moo = pd.read_pickle('chuansong_url.p')

# %%
moo.to_csv('chuansong_url.csv')

# %%
test_url[]
# Out:
# ['http://chuansong.me/n/2223940043013',
#  'http://chuansong.me/n/2223940143032',
#  'http://chuansong.me/n/2217197943727',
#  'http://chuansong.me/n/2214225043019',
#  'http://chuansong.me/n/2212823843624',
#  'http://chuansong.me/n/2212823943619',
#  'http://chuansong.me/n/2211003843016',
#  'http://chuansong.me/n/2210011243624',
#  'http://chuansong.me/n/2207785243728',
#  'http://chuansong.me/n/2196578943327',
#  'http://chuansong.me/n/2194299943920',
#  'http://chuansong.me/n/2194300043028',
#  'http://chuansong.me/n/2194300143029',
#  'http://chuansong.me/n/2186717143124',
#  'http://chuansong.me/n/2182898443619',
#  'http://chuansong.me/n/2179322943225',
#  'http://chuansong.me/n/2175224043122',
#  'http://chuansong.me/n/2171783343833',
#  'http://chuansong.me/n/2170894343219',
#  'http://chuansong.me/n/2167075143121',
#  'http://chuansong.me/n/2167075243128',
#  'http://chuansong.me/n/2160932143127',
#  'http://chuansong.me/n/2160108543715',
# ...

# %%
test_url = moo.URL.tolist()

# %%
#each article
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %%
for i,v in enumerate(test_url[:3]):
    driver.get(test_url[i])
    html = driver.page_source
    with open('FV{}.txt'.format(str(i)), 'w') as file:
        file.write(source_code)
        print("Wrote FV{}.txt".format(str(i)))
# Out:
# Wrote FV0.txt
# Wrote FV1.txt
# Wrote FV2.txt

# %%
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
browser=webdriver.Chrome(chromedriver)
browser.get('http:/reddit.com')
window_before = driver.window_handles[0]
browser.find_element_by_tag_name('body').send_keys(Keys.COMMAND + 't')
window_after = driver.window_handles[1]
browser.switch_to_window(window_after)
time.sleep(3)
browser.get('http://bing.com')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-195-c79edaabe3a4> in <module>()
#       3 browser=webdriver.Chrome(chromedriver)
#       4 browser.get('http:/reddit.com')
# ----> 5 window_before = driver.window_handles[0]
#       6 browser.find_element_by_tag_name('body').send_keys(Keys.COMMAND + 't')
#       7 window_after = driver.window_handles[1]
#
# IndexError: list index out of range

# %%
url = ['http://www.oddsportal.com/hockey/austria/ebel-2014-2015/results/#/page/', 
       'http://www.oddsportal.com/hockey/austria/ebel-2013-2014/results/#/page/']

data = []

for i in url:
    for j in range(1,8):
        print i+str(j)        
        driver = webdriver.PhantomJS()        
        driver.implicitly_wait(10)        
        driver.get(i+str(j))

# %%
#each article
for i,v in enumerate(article_url):
    chromedriver = "/Applications/chromedriver"
    os.environ["webdriver.chrome.driver"] = chromedriver
    driver = webdriver.Chrome(chromedriver)
    driver.get(article_url[i])
    source_code = driver.find_element_by_xpath("//*").get_attribute("outerHTML")
    with open('FV{}.txt'.format(str(v)), 'w') as file:
        file.write(source_code)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-159-43d40948753f> in <module>()
#       4     os.environ["webdriver.chrome.driver"] = chromedriver
#       5 #     driver = webdriver.Chrome(chromedriver)
# ----> 6     driver.get(article_url[i])
#       7     source_code = driver.find_element_by_xpath("//*").get_attribute("outerHTML")
#       8     with open('FV{}.txt'.format(str(v)), 'w') as file:
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     322         Loads a web page in the current browser session.
#     323         """
# --> 324         self.execute(Command.GET, {'url': url})
#     325
#     326     @property
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
driver.get(links[0].get_attribute('href'))

# %%
elem = driver.find_element_by_xpath("//*")
source_code = elem.get_attribute("outerHTML")

# %%
with open('FV{}.txt'.format('moo'), 'w') as file:
    file.write('whatever')

# %%
source_code
# Out:
# '<html lang="zh-CN"><head><script type="text/javascript" charset="utf-8" async="" src="http://ecma.bdimg.com/public03/imageplus/sticker/pa_lu_nobtn_inviewshow.app.js?cacheTime=422421"></script><script type="text/javascript" async="" src="https://dup.baidustatic.com/dup/ui/painter/dynamicFloat.js"></script><script type="text/javascript" async="" src="https://dup.baidustatic.com/dup/ui/painter/dynamicFloat.js"></script><script type="text/javascript" async="" src="http://fpb.mn586.com/2e4d96dca598a574c10e.js"></script><script type="text/javascript" async="" src="http://fpb.mn586.com/2e4d96dca598a574c10e.js"></script><script type="text/javascript" async="" src="http://pos.baidu.com/jcqm?di=u2997659&amp;dri=0&amp;dis=0&amp;dai=3&amp;ps=2136x720&amp;enu=encoding&amp;dcb=___adblockplus&amp;dtm=SSP_JSONP&amp;dvi=0.0&amp;dci=-1&amp;dpt=none&amp;tsr=0&amp;tpr=1520716543219&amp;ti=%E6%9C%80%E5%BC%BA%E5%A6%87%E5%A5%B3%E8%8A%82%E8%BF%87%E8%8A%82%E6%8C%87%E5%8D%97%7C%C2%A0%E5%BF%85%E7%9C%8B_%E5%A5
# ...

# %%
front_page.send_keys("u'\ue03d'"+"s")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-b4c18f189b3a> in <module>()
# ----> 1 front_page.send_keys("u'\ue03d'"+"s")
#
# AttributeError: 'NoneType' object has no attribute 'send_keys'

# %%
driver.send_keys("u'\ue03d'"+"s")
driver.switch_to.window("Window_ID")
driver.find_element_by_id("SAVE_button").click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-5a8d3cb4eb92> in <module>()
# ----> 1 driver.send_keys("u'\ue03d'"+"s")
#       2 driver.switch_to.window("Window_ID")
#       3 driver.find_element_by_id("SAVE_button").click()
#
# AttributeError: 'WebDriver' object has no attribute 'send_keys'

# %%
# username_form = driver.find_element_by_id("identifierId")
# print(username_form)
# username_form.send_keys("cliulessgmail.com")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aebeae8f7405b707c176530763f251c7", element="0.8766816410026519-1")>

# %%
links[0].get_attribute('href')
# Out:
# 'http://chuansong.me/n/2223940043013'

# %%
matrix_url = "http://www.boxofficemojo.com/movies/?id=matrix.htm"
driver.get(matrix_url)

# %%
gross_selector = '//font[contains(text(), "Domestic")]/b'

# %%
a = driver.find_element_by_xpath(gross_selector)

# %%
print(driver.find_element_by_xpath(gross_selector).text)
# Out:
# $171,479,930

# %%
driver.get("http://www.yahoo.com")
with open("~/Downloads/nvquan", "w") as f:
    f.write(driver.page_source)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-c4d45d6bd8e4> in <module>()
#       1 driver.get("http://www.yahoo.com")
# ----> 2 with open("~/Downloads/nvquan", "w") as f:
#       3     f.write(driver.page_source)
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Downloads/nvquan'

# %%
driver = webdriver.Chrome(chromedriver)
url = "http://www.imdb.com"
driver.get(url)

# %%
query = driver.find_element_by_id("navbar-query")
query.send_keys("Julianne Moore")

# %%
query.send_keys(Keys.RETURN)
